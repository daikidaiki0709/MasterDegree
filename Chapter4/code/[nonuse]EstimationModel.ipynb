# %%
# import系
import time
import numpy as np
import pandas as pd
from sklearn.metrics import r2_score,  mean_squared_error
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split, KFold
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
from scipy.optimize import curve_fit
from scipy import signal
import statsmodels.formula.api as smf
import statsmodels.api as sm

from estimation_func import linear_model, linearregression_6, linearregression_7, holdout

# %%
# 特徴量
feature_3mm_11mm_scale = pd.read_csv('./../data/feature_3mm_11mm_scale.csv',index_col=0)
feature_3mm_36mm_scale = pd.read_csv('./../data/feature_3mm_36mm_scale.csv',index_col=0)

# 目的変数
firmness_all = pd.read_excel('./../data/2020_さんふじ_硬さ.xlsx',index_col=0)
firmness_all = 9.81*firmness_all # kgからNに変換

# %% [markdown]
# ## 線形回帰の結果を格納

# %%
obs_pred_6week_36 = linear_model(feature_3mm_36mm_scale,firmness_all,6)
obs_pred_7week_36 = linear_model(feature_3mm_36mm_scale,firmness_all,7)
obs_pred_6week_15 = linear_model(feature_3mm_11mm_scale,firmness_all,6)
obs_pred_7week_15 = linear_model(feature_3mm_11mm_scale,firmness_all,7)

# %% [markdown]
# ## 全サンプルの結果を格納

# %%
linearregression_6(obs_pred_6week_36)
# Out:
# RMSE_0week : 1.6019105375269476
# RMSE_1week : 0.966966190932837
# RMSE_2week : 1.118743903891692
# RMSE_3week : 0.9374209753827988
# RMSE_4week : 1.158439841949
# RMSE_5week : 0.8796282311406068
# RMSE_6week : 1.2424093525421167
# /Users/daiki/python_enviroment/MasterDegree/Chapter4/code/estimation_func.py:68: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   y_pred_0.append(target['Predict'][i])
# /Users/daiki/python_enviroment/MasterDegree/Chapter4/code/estimation_func.py:69: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   y_real_0.append(target['Actual'][i])
# ...

# %%
linearregression_7(obs_pred_7week_36)
# Out:
# RMSE_0week : 1.8513983566266967
# Mean of Measured  Firmness 0week : 25.683056875
#
# Mean of Predicted Firmness 0week : 24.14014457214323
#
# RMSE_0week : 1.8513983566266967
# ----------
# RMSE_1week : 1.3553794825087362
# Mean of Measured  Firmness 1week : 24.42403875
#
# Mean of Predicted Firmness 1week : 23.68395334644986
#
# RMSE_1week : 1.3553794825087362
# ----------
# RMSE_2week : 1.3552684176856546
# Mean of Measured  Firmness 2week : 23.78816
#
# Mean of Predicted Firmness 2week : 23.529530397372163
#
# RMSE_2week : 1.3552684176856546
# ----------
# RMSE_3week : 1.0666029859928354
# Mean of Measured  Firmness 3week : 23.159775000000003
#
# Mean of Predicted Firmness 3week : 23.245669404505147
#
# RMSE_3week : 1.0666029859928354
# ----------
# RMSE_4week : 1.1760967853431652
# Mean of Measured  Firmness 4week : 22.717779999999998
#
# Mean of Predicted Firmness 4week : 23.019207430920368
#
# RMSE_4week : 1.1760967853431652
# ----------
# RMSE_5week : 1.035939045927808
# ...

# %% [markdown]
# ## 汎化性能

# %%
holdout(feature_3mm_11mm_scale,firmness_all)
# Out:
# /Users/daiki/python_enviroment/MasterDegree/Chapter4/code/estimation_func.py:294: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels([18,20,22,24,26,28],fontsize=28)
# /Users/daiki/python_enviroment/MasterDegree/Chapter4/code/estimation_func.py:295: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_yticklabels([18,20,22,24,26,28],fontsize=28)

# %%
holdout(feature_3mm_36mm_scale,firmness_all)
# Out:
# /Users/daiki/python_enviroment/MasterDegree/Chapter4/code/estimation_func.py:294: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels([18,20,22,24,26,28],fontsize=28)
# /Users/daiki/python_enviroment/MasterDegree/Chapter4/code/estimation_func.py:295: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_yticklabels([18,20,22,24,26,28],fontsize=28)
