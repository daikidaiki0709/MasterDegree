# %%
# %%time

import matplotlib.pyplot as plt
import time
from calc_texture import compare_texture_line

column_list = ['firmness_skin','firmness_flesh_only','CI_flesh_only']

for i,temp in enumerate(column_list):
    fig = compare_texture_line(column=temp)
    fig.savefig(f'./../output/図{26+i}_compare_{temp}.png',dpi=400)
    plt.close()
# Out:
# /Users/daiki/python_enviroment/MasterDegree/Chapter5_2/code/calc_texture.py:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   index = df.index).applymap(func)
# /Users/daiki/python_enviroment/MasterDegree/Chapter5_2/code/calc_texture.py:35: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   index = df.index).applymap(func)
# /Users/daiki/python_enviroment/MasterDegree/Chapter5_2/code/calc_texture.py:55: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   labels = [i+1 for i in range(int(df['period'][-1]))]
# /Users/daiki/python_enviroment/MasterDegree/Chapter5_2/code/calc_texture.py:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   index = df.index).applymap(func)
# ...

# %% [markdown]
# ## targetどうしの相関関係

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('./../data/texture_all.csv',header=0,index_col=0)
df = df.loc[:, ['firmness_skin','firmness_flesh_only','CI_flesh_only']]
df.corr()
# Out:
#                      firmness_skin  firmness_flesh_only  CI_flesh_only
# firmness_skin             1.000000             0.776744       0.728493
# firmness_flesh_only       0.776744             1.000000       0.779204
# CI_flesh_only             0.728493             0.779204       1.000000
